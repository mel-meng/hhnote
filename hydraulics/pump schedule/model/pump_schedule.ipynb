# %%
import pandas as pd

# %%
df = pd.read_excel('./data.xlsx')

# %%
ax = df.plot(x='minute', y='status', drawstyle="steps")
ax.set_title('Pump Status 1=ON 0=OFF')
# Out:
# Text(0.5, 1.0, 'Pump Status 1=ON 0=OFF')
